# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
data_down = pd.read_csv('Data_down.csv', sep='\s+')  #your oath here 
data_up = pd.read_csv('Data_up.csv', sep='\s+')    #your oath here

# %%
data_down.head()
# Out:
#    timestamp  rawTimesamp  distance        lat       lon     alt  speed   acc  \
# 0      10.33   1544432937     99.42  51.490553  7.413966  157.63  11.83  0.00
# 1      21.87   1544432949    237.43  51.490715  7.416002  152.41  10.76 -0.52
# 2      32.46   1544432959    325.26  51.490668  7.417176  154.64   6.19 -0.62
# 3      46.40   1544432973    448.27  51.491839  7.416804  155.87   9.77 -0.98
# 4      54.95   1544432982    540.48  51.492531  7.416222  154.41  12.33  0.01
#
#       dir  connected  rsrp  rsrq  sinr  cqi  ss  ta        ci  pci  id  \
# 0   79.35          1   -85    -5    22   10  50   7  26385408   95   0
# 1   89.45          1   -84    -6    11   13  52   4  29391105  167   1
# 2   27.05          1   -82    -6    21   15  54   4  29391105  167   2
# 3  342.45          1   -94    -9     9    9  45   4  29391105  167   3
# 4  336.68          1   -90    -6    16    9  45   4  29391105  167   4
#
#    payload  throughput  rtt  measurement location
# 0      0.1     6.83763   41   1544432927   campus
# 1      2.0     9.71463   58   1544432927   campus
# 2      2.0     7.30594   57   1544432927   campus
# 3      3.0     3.94997  163   1544432927   campus
# 4      5.0     8.54884   59   1544432927   campus

# %%
data_up.head()
# Out:
#    timestamp  rawTimesamp  distance        lat       lon     alt  speed   acc  \
# 0      11.53   1544432938    113.75  51.490592  7.414306  156.39  12.21  0.50
# 1      21.33   1544432948    231.40  51.490717  7.415835  152.53  11.17  0.00
# 2      32.22   1544432959    323.73  51.490634  7.417138  154.23   6.44  0.00
# 3      54.69   1544432982    537.34  51.492531  7.416222  154.41  12.33  0.02
# 4      63.98   1544432991    650.07  51.493484  7.415836  153.05  11.69 -0.18
#
#       dir  connected  rsrp  rsrq  sinr  cqi  ss  ta        ci  pci  id  \
# 0   77.59          1   -85    -5    22   10  50   7  26385408   95   0
# 1   87.24          1   -84    -6    11   13  52   4  29391105  167   1
# 2   48.55          1   -82    -6    21   15  54   4  29391105  167   2
# 3  336.68          1   -90    -6    16    9  45   4  29391105  167   4
# 4  348.09          1  -101   -10    13   15  40   4  29391105  167   5
#
#    payload  throughput  rtt   txPower  measurement location
# 0      4.0     24.5211   35  12.30470   1544432927   campus
# 1      2.0     14.8561   51  10.01560   1544432927   campus
# 2      4.0     16.2684   57   4.34375   1544432927   campus
# 3      8.0     14.5886   60  17.31250   1544432927   campus
# 4      6.0     13.1255   57  19.93750   1544432927   campus

# %%
data_up.columns
# Out:
# Index(['timestamp', 'rawTimesamp', 'distance', 'lat', 'lon', 'alt', 'speed',
#        'acc', 'dir', 'connected', 'rsrp', 'rsrq', 'sinr', 'cqi', 'ss', 'ta',
#        'ci', 'pci', 'id', 'payload', 'throughput', 'rtt', 'txPower',
#        'measurement', 'location'],
#       dtype='object')

# %%
data_down.columns
# Out:
# Index(['timestamp', 'rawTimesamp', 'distance', 'lat', 'lon', 'alt', 'speed',
#        'acc', 'dir', 'connected', 'rsrp', 'rsrq', 'sinr', 'cqi', 'ss', 'ta',
#        'ci', 'pci', 'id', 'payload', 'throughput', 'rtt', 'measurement',
#        'location'],
#       dtype='object')

# %%
data_down.dtypes
# Out:
# timestamp      float64
# rawTimesamp      int64
# distance       float64
# lat            float64
# lon            float64
# alt            float64
# speed          float64
# acc            float64
# dir            float64
# connected        int64
# rsrp             int64
# rsrq             int64
# sinr             int64
# cqi              int64
# ss               int64
# ta               int64
# ci               int64
# pci              int64
# id               int64
# payload        float64
# throughput     float64
# rtt              int64
# measurement      int64
# location        object
# dtype: object

# %%
data_up.dtypes
# Out:
# timestamp      float64
# rawTimesamp      int64
# distance       float64
# lat            float64
# lon            float64
# alt            float64
# speed          float64
# acc            float64
# dir            float64
# connected        int64
# rsrp             int64
# rsrq             int64
# sinr             int64
# cqi              int64
# ss               int64
# ta               int64
# ci               int64
# pci              int64
# id               int64
# payload        float64
# throughput     float64
# rtt              int64
# txPower        float64
# measurement      int64
# location        object
# dtype: object

# %%
data_down.describe()
# Out:
#          timestamp   rawTimesamp      distance          lat          lon  \
# count  2141.000000  2.141000e+03   2141.000000  2141.000000  2141.000000
# mean    355.080486  1.545881e+09   4273.932844    51.478644     7.445595
# std     245.995297  1.395781e+06   3774.430086     0.022528     0.030796
# min       9.930000  1.544433e+09     99.420000    51.437142     7.393019
# 25%     152.540000  1.544680e+09   1365.830000    51.463083     7.416637
# 50%     301.880000  1.545135e+09   2825.780000    51.481652     7.450149
# 75%     532.810000  1.547616e+09   6435.790000    51.490668     7.473018
# max    1040.950000  1.547803e+09  14124.020000    51.517905     7.491755
#
#                alt        speed          acc          dir  connected  \
# count  2141.000000  2141.000000  2141.000000  2141.000000     2141.0
# mean    177.235390    12.154703     0.004447   164.828720        1.0
# std      41.975692     8.870322     1.123975    93.178596        0.0
# min     125.060000     0.000000   -11.050000     0.030000        1.0
# 25%     152.000000     6.860000     0.000000    92.300000        1.0
# 50%     163.700000    12.450000     0.000000   150.270000        1.0
# 75%     181.920000    14.990000     0.000000   250.640000        1.0
# max     297.820000    39.340000    17.260000   359.980000        1.0
#
#               rsrp         rsrq         sinr          cqi           ss  \
# count  2141.000000  2141.000000  2141.000000  2141.000000  2141.000000
# mean    -88.519851    -7.463802    13.448389     9.931808    49.235871
# std       9.314856     2.091197     9.788405     3.325492     7.719616
# min    -113.000000   -19.000000   -15.000000     1.000000    27.000000
# 25%     -95.000000    -9.000000     6.000000     7.000000    44.000000
# 50%     -89.000000    -7.000000    12.000000    10.000000    49.000000
# 75%     -83.000000    -6.000000    21.000000    12.000000    54.000000
# max     -56.000000    -4.000000    40.000000    15.000000    63.000000
#
#                 ta            ci          pci           id      payload  \
# count  2141.000000  2.141000e+03  2141.000000  2141.000000  2141.000000
# mean      7.036432  2.841641e+07   247.065390    34.203176     4.517468
# std       6.221577  1.592816e+06   141.441334    24.617168     3.232045
# min       0.000000  2.637671e+07    24.000000     0.000000     0.100000
# 25%       3.000000  2.729933e+07    95.000000    14.000000     1.000000
# 50%       6.000000  2.836506e+07   222.000000    29.000000     4.000000
# 75%       9.000000  2.939828e+07   375.000000    52.000000     7.000000
# max      94.000000  3.383757e+07   496.000000   103.000000    10.000000
#
#         throughput          rtt   measurement
# count  2141.000000  2141.000000  2.141000e+03
# mean     13.125105    71.218589  1.545881e+09
# std       7.200611   166.581665  1.395804e+06
# min       0.070194    29.000000  1.544433e+09
# 25%       7.312610    37.000000  1.544679e+09
# 50%      12.350400    46.000000  1.545134e+09
# 75%      17.937200    71.000000  1.547616e+09
# max      43.010800  5323.000000  1.547803e+09

# %%
data_down.isnull().values.any()
# Out:
# False

# %%
data_up.isnull().values.any()
# Out:
# False

# %%
locations_list = list(data_down['location'].unique())
def group_count(df, locations, groupby_1, groupby_2,groupby_3 ):
    
    describtion = pd.DataFrame(columns =['location', 'measurement_count', 'pci_count', 'ci_count'])
    for loc in locations:
        location = df[df['location'] == loc]
        
        describtion= describtion.append({
            'location': loc,
            'measurement_count': location.groupby(groupby_1).count().shape[0],
            'pci_count': location.groupby(groupby_2).count().shape[0],
            'ci_count': location.groupby(groupby_3).count().shape[0]
        }, 
            ignore_index=True)
        
    return describtion

# %%
down_unique_describtion = group_count(data_down,locations_list, 'measurement', 'pci', 'ci')
down_unique_describtion
# Out:
#    location measurement_count pci_count ci_count
# 0    campus                10         5        5
# 1   highway                10        29       31
# 2  suburban                10        22       22
# 3     urban                10        12       12

# %%
upload_unique_describtion = group_count(data_up,locations_list, 'measurement', 'pci', 'ci')
upload_unique_describtion
# Out:
#    location measurement_count pci_count ci_count
# 0    campus                10         5        5
# 1   highway                10        29       31
# 2  suburban                10        22       22
# 3     urban                10        11       11

# %% [markdown]
# #  visualizations

# %%
def plot_2_hist(df1, df2, x1, x2, title1 ="", title2=""):

    _, axes = plt.subplots(1, 2, figsize=(16, 8))

    ax1 = sns.histplot(data=df1, x=x1,
                    kde=True, ax=axes[0])
    ax1.set_title(title1, loc='left')

    ax2 = sns.histplot(data=df2, x=x2,
                    kde=True, ax=axes[1])
    ax2.set_title(title2, loc='left')


    plt.show()
    
def plot_2_boxplot(x1, x2, title1 ="", title2=""):

    _, axes = plt.subplots(1, 2, figsize=(16, 8))

    ax1 = sns.boxplot(x=x1, ax=axes[0])
    ax1.set_title(title1, loc='left')

    ax2 = sns.boxplot(x=x2, ax=axes[1])
    ax2.set_title(title2, loc='left')


    plt.show()

# %%
plot_2_hist(data_down, data_up,data_down["throughput"], data_up["throughput"],
            title1 = "Download Throughput", title2 = "Upload Throughput")

# %%
plot_2_hist(data_down, data_up,data_down["speed"], data_up["speed"],
            title1 = "Spead Download-Data", title2 = "Spead Upload-Data")

# %%
plot_2_hist(data_down, data_up,data_down["acc"], data_up["acc"],
            title1 = "Acceleration Download-Data", title2 = "Acceleration Upload-Data")

# %%
plot_2_boxplot(data_down["throughput"], data_up["throughput"],
              title1 = "Download Throughout", title2="Upload throughput")

# %%
plot_2_boxplot(data_down["speed"], data_up["speed"],
              title1 = "Spead Download-Data", title2="Spead Upload-Data")
